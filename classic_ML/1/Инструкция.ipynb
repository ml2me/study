# %% [markdown]
# # **Инструкция по настройке виртуального окружения**

# %% [markdown]
# Использование разных версий библиотек может привести к тому, что при исполнении одного и того же кода результаты будут отличаться.
#
# Перед началом работы с заданиями курса необходимо правильно настроить виртуальное окружение Python, что обеспечит:
#
# * Воспроизводимость результатов.
#
# * Совместимость версий библиотек.
#
# * Изолированность виртуальной среды от других проектов.
#
# Инструкция призвана помочь в настройке виртуального окружения Python для работы в:
#
# * Облачные среды: Google Colab/Kaggle.
#
# * Локальные среды: venv и Conda.

# %% [markdown]
# ## **Проверка настройки виртуального окружения**

# %% [markdown]
# Для проверки настройки виртуального окружения перед тем, как приступить к выполнению заданий курса, **в каждом ноутбуке с домашним заданием** выполняйте код в ячейке ниже **после каждого нового запуска ноутбука**.

# %%
# Код для проверки настройки виртуального окружения

import sys
from importlib.metadata import version

required = {
    'python': '3.12.x',
    'scipy': '1.16.3',
    'numpy': '2.0.2',
    'pandas': '2.2.2',
    'scikit-learn': '1.6.1',
    'statsmodels': '0.14.6',
    'matplotlib': '3.10.0',
    'seaborn': '0.13.2',
    'nltk': '3.9.1',
    'missingno': '0.5.2',
    'mlxtend': '0.23.4',
    'graphviz': '0.21',
    'catboost': '1.2.8',
    'lightgbm': '4.6.0',
    'xgboost': '3.1.3',
    'optuna': '4.4.0',
    'eli5': '0.16.0',
    'shap': '0.50.0'
}

print(f'{"Компонент":<15} | {"Требуется":<12} | {"Установлено":<12} | {"Соответствие"}')
print('-' * 62)

environment_ok = True
for lib, req_ver in required.items():
    try:
        if lib=='python':
            inst_ver = sys.version.split()[0]
            status = '✓' if sys.version_info.major == 3 and sys.version_info.minor == 12 else f'x (требуется {req_ver})'
        else:
            inst_ver = version(lib)
            if inst_ver == req_ver:
                status = '✓'
            else:
                environment_ok = False
                status = f'x (требуется {req_ver})'
    except:
        environment_ok = False
        inst_ver = '-'
        status = 'x (не установлена)'
    print(f'{lib:<15} | {req_ver:<12} | {inst_ver:<12} | {status:<12}')

print('\nРезультат проверки: ', 
      '✓\nВсе версии соответствуют требованиям' 
      if environment_ok else 
      'x\nВНИМАНИЕ: Версии некоторых компонентов не соответствуют требованиям!\n'
      'Для решения проблемы обратитесь к инструкции по настройке виртуального окружения')
# Out:
# Компонент       | Требуется    | Установлено  | Соответствие
# --------------------------------------------------------------
# python          | 3.12.x       | 3.12.10      | ✓
# scipy           | 1.16.3       | 1.17.0       | x (требуется 1.16.3)
# numpy           | 2.0.2        | 2.4.2        | x (требуется 2.0.2)
# pandas          | 2.2.2        | 3.0.0        | x (требуется 2.2.2)
# scikit-learn    | 1.6.1        | 1.6.1        | ✓
# statsmodels     | 0.14.6       | 0.14.6       | ✓
# matplotlib      | 3.10.0       | 3.10.0       | ✓
# seaborn         | 0.13.2       | 0.13.2       | ✓
# nltk            | 3.9.1        | 3.9.1        | ✓
# missingno       | 0.5.2        | 0.5.2        | ✓
# mlxtend         | 0.23.4       | 0.23.4       | ✓
# graphviz        | 0.21         | 0.21         | ✓
# catboost        | 1.2.8        | 1.2.8        | ✓
# lightgbm        | 4.6.0        | 4.6.0        | ✓
# xgboost         | 3.1.3        | 3.1.3        | ✓
# optuna          | 4.4.0        | 4.4.0        | ✓
# eli5            | 0.16.0       | 0.16.0       | ✓
# shap            | 0.50.0       | 0.50.0       | ✓
#
# Результат проверки:  x
# ВНИМАНИЕ: Версии некоторых компонентов не соответствуют требованиям!
# Для решения проблемы обратитесь к инструкции по настройке виртуального окружения

# %% [markdown]
# ## **Настройка для облачных сред: [Google Colab](https://colab.research.google.com/?hl=ru)/[Kaggle](https://www.kaggle.com/docs/notebooks)**

# %% [markdown]
# Google Colab и Kaggle не поддерживают прямое использование локальных виртуальных окружений Python.
#
# В этом случае предлагается установить нужные версии библиотек напрямую в среду исполнения.
#
# **ВНИМАНИЕ.** При новом запуске ноутбука с заданиями требуется повторная настройка.

# %%
# %pip install scikit-learn==1.6.1 statsmodels==0.14.6 matplotlib==3.10.0 seaborn==0.13.2 nltk==3.9.1 missingno==0.5.2 mlxtend==0.23.4 graphviz==0.21 catboost==1.2.8 lightgbm==4.6.0 xgboost==3.1.3 optuna==4.4.0 eli5==0.16.0 shap==0.50.0
# Out:
# Collecting scikit-learn==1.6.1
#   Downloading scikit_learn-1.6.1-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Collecting statsmodels==0.14.6
#   Downloading statsmodels-0.14.6-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Collecting matplotlib==3.10.0
#   Downloading matplotlib-3.10.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting seaborn==0.13.2
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting nltk==3.9.1
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting missingno==0.5.2
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Collecting mlxtend==0.23.4
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Collecting graphviz==0.21
#   Downloading graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Collecting catboost==1.2.8
#   Downloading catboost-1.2.8-cp312-cp312-win_amd64.whl.metadata (1.5 kB)
# Collecting lightgbm==4.6.0
#   Downloading lightgbm-4.6.0-py3-none-win_amd64.whl.metadata (17 kB)
# Collecting xgboost==3.1.3
#   Downloading xgboost-3.1.3-py3-none-win_amd64.whl.metadata (2.0 kB)
# Collecting optuna==4.4.0
#   Downloading optuna-4.4.0-py3-none-any.whl.metadata (17 kB)
# Collecting eli5==0.16.0
#   Downloading eli5-0.16.0-py2.py3-none-any.whl.metadata (18 kB)
# Collecting shap==0.50.0
#   Downloading shap-0.50.0-cp312-cp312-win_amd64.whl.metadata (25 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\Users\user\ml2me\myenv\Lib\site-packages (from scikit-learn==1.6.1) (2.4.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\Users\user\ml2me\myenv\Lib\site-packages (from scikit-learn==1.6.1) (1.17.0)
# Collecting joblib>=1.2.0 (from scikit-learn==1.6.1)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn==1.6.1)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\Users\user\ml2me\myenv\Lib\site-packages (from statsmodels==0.14.6) (3.0.0)
# Collecting patsy>=0.5.6 (from statsmodels==0.14.6)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: packaging>=21.3 in c:\Users\user\ml2me\myenv\Lib\site-packages (from statsmodels==0.14.6) (26.0)
# Collecting contourpy>=1.0.1 (from matplotlib==3.10.0)
#   Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib==3.10.0)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib==3.10.0)
#   Downloading fonttools-4.61.1-cp312-cp312-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib==3.10.0)
#   Downloading kiwisolver-1.4.9-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Collecting pillow>=8 (from matplotlib==3.10.0)
#   Downloading pillow-12.1.1-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib==3.10.0)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\user\ml2me\myenv\Lib\site-packages (from matplotlib==3.10.0) (2.9.0.post0)
# Collecting click (from nltk==3.9.1)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting regex>=2021.8.3 (from nltk==3.9.1)
#   Downloading regex-2026.1.15-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk==3.9.1)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting plotly (from catboost==1.2.8)
#   Downloading plotly-6.5.2-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: six in c:\Users\user\ml2me\myenv\Lib\site-packages (from catboost==1.2.8) (1.17.0)
# Collecting alembic>=1.5.0 (from optuna==4.4.0)
#   Downloading alembic-1.18.4-py3-none-any.whl.metadata (7.2 kB)
# Collecting colorlog (from optuna==4.4.0)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Collecting sqlalchemy>=1.4.2 (from optuna==4.4.0)
#   Downloading sqlalchemy-2.0.46-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Collecting PyYAML (from optuna==4.4.0)
#   Downloading pyyaml-6.0.3-cp312-cp312-win_amd64.whl.metadata (2.4 kB)
# Collecting attrs>17.1.0 (from eli5==0.16.0)
#   Downloading attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting jinja2>=3.0.0 (from eli5==0.16.0)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting tabulate>=0.7.7 (from eli5==0.16.0)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting slicer==0.0.8 (from shap==0.50.0)
#   Downloading slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Collecting numba>=0.54 (from shap==0.50.0)
#   Downloading numba-0.64.0-cp312-cp312-win_amd64.whl.metadata (3.0 kB)
# Collecting cloudpickle (from shap==0.50.0)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-extensions (from shap==0.50.0)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting Mako (from alembic>=1.5.0->optuna==4.4.0)
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Collecting MarkupSafe>=2.0 (from jinja2>=3.0.0->eli5==0.16.0)
#   Downloading markupsafe-3.0.3-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Collecting llvmlite<0.47,>=0.46.0dev0 (from numba>=0.54->shap==0.50.0)
#   Downloading llvmlite-0.46.0-cp312-cp312-win_amd64.whl.metadata (5.1 kB)
# Requirement already satisfied: tzdata in c:\Users\user\ml2me\myenv\Lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels==0.14.6) (2025.3)
# Collecting greenlet>=1 (from sqlalchemy>=1.4.2->optuna==4.4.0)
#   Downloading greenlet-3.3.1-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: colorama in c:\Users\user\ml2me\myenv\Lib\site-packages (from tqdm->nltk==3.9.1) (0.4.6)
# Collecting narwhals>=1.15.1 (from plotly->catboost==1.2.8)
#   Downloading narwhals-2.16.0-py3-none-any.whl.metadata (14 kB)
# Downloading scikit_learn-1.6.1-cp312-cp312-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    -------- ------------------------------- 2.4/11.1 MB 15.0 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.1 MB 19.8 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 20.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 17.8 MB/s  0:00:00
# Downloading statsmodels-0.14.6-cp312-cp312-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ------------------- -------------------- 4.7/9.5 MB 23.7 MB/s eta 0:00:01
#    ------------------------------------- -- 8.9/9.5 MB 22.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 19.1 MB/s  0:00:00
# Downloading matplotlib-3.10.0-cp312-cp312-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ----------------------- ---------------- 4.7/8.0 MB 23.8 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 23.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 17.2 MB/s  0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 15.9 MB/s  0:00:00
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 17.6 MB/s  0:00:00
# Downloading graphviz-0.21-py3-none-any.whl (47 kB)
# Downloading catboost-1.2.8-cp312-cp312-win_amd64.whl (102.4 MB)
#    ---------------------------------------- 0.0/102.4 MB ? eta -:--:--
#    - -------------------------------------- 4.7/102.4 MB 23.7 MB/s eta 0:00:05
#    --- ------------------------------------ 9.7/102.4 MB 23.2 MB/s eta 0:00:04
#    ----- ---------------------------------- 14.2/102.4 MB 22.8 MB/s eta 0:00:04
#    ------- -------------------------------- 19.4/102.4 MB 23.1 MB/s eta 0:00:04
#    --------- ------------------------------ 23.6/102.4 MB 22.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 27.8/102.4 MB 22.3 MB/s eta 0:00:04
#    ------------ --------------------------- 31.5/102.4 MB 21.5 MB/s eta 0:00:04
#    ------------- -------------------------- 35.1/102.4 MB 21.1 MB/s eta 0:00:04
#    --------------- ------------------------ 39.3/102.4 MB 20.8 MB/s eta 0:00:04
#    ---------------- -----------------------
#    --------------------------------- ------ 59.5/72.0 MB 4.6 MB/s eta 0:00:03
#    --------------------------------- ------ 60.0/72.0 MB 4.5 MB/s eta 0:00:03
#    --------------------------------- ------ 60.3/72.0 MB 4.5 MB/s eta 0:00:03
#    --------------------------------- ------ 60.8/72.0 MB 4.4 MB/s eta 0:00:03
#    --------------------------------- ------ 61.1/72.0 MB 4.4 MB/s eta 0:00:03
#    ---------------------------------- ----- 61.6/72.0 MB 4.4 MB/s eta 0:00:03
#    ---------------------------------- ----- 62.1/72.0 MB 4.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 62.4/72.0 MB 4.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 62.9/72.0 MB 4.2 MB/s eta 0:00:03
#    ----------------------------------- ---- 63.4/72.0 MB 4.2 MB/s eta 0:00:03
#    ----------------------------------- ---- 63.7/72.0 MB 4.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 64.2/72.0 MB 4.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 64.7/72.0 MB 4.1 MB/s eta 0:00:02
#    ------------------------------------ --- 65.0/72.0 MB 4.1 MB/s eta 0:00:02
#    ------------------------------------ --- 65.5/72.0 MB 4.1 MB/s eta 0:00:02
#    ------------------------------------ --- 66.1/72.0 MB 4.1 MB/s eta 0:00:02
#    ------------------------------------ --- 66.6/72.0 MB 4.0 MB/s eta 0:00:02
#    ------------------------------------- -- 67.1/72.0 MB 4.0 MB/s eta 0:00:02
#    ------------------------------------- -- 67.6/72.0 MB 4.0 MB/s eta 0:00:02
#    ------------------------------------- -- 68.2/72.0 MB 4.0 MB/s eta 0:00:01
#    -------------------------------------- - 68.7/72.0 MB 4.0 MB/s eta 0:00:01
#    -------------------------------------- - 69.2/72.0 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 69.7/72.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  70.5/72.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  71.0/72.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  71.6/72.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  71.8/72.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  71.8/72.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  71.8/72.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 72.0/72.0 MB 3.7 MB/s  0:00:19
# Downloading optuna-4.4.0-py3-none-any.whl (395 kB)
# Downloading eli5-0.16.0-py2.py3-none-any.whl (108 kB)
# Downloading shap-0.50.0-cp312-cp312-win_amd64.whl (549 kB)
#    ---------------------------------------- 0.0/549.3 kB ? eta -:--:--
#    ---------------------------------------- 549.3/549.3 kB 3.1 MB/s  0:00:00
# Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Downloading alembic-1.18.4-py3-none-any.whl (263 kB)
# Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp312-cp312-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.3 MB 2.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.3/2.3 MB 3.2 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 3.0 MB/s  0:00:00
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading kiwisolver-1.4.9-cp312-cp312-win_amd64.whl (73 kB)
# Downloading markupsafe-3.0.3-cp312-cp312-win_amd64.whl (15 kB)
# Downloading numba-0.64.0-cp312-cp312-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.8 MB 4.2 MB/s eta 0:00:01
#    --------------- ------------------------ 1.0/2.8 MB 3.6 MB/s eta 0:00:01
#    -------------------------- ------------- 1.8/2.8 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.4/2.8 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 2.8 MB/s  0:00:00
# Downloading llvmlite-0.46.0-cp312-cp312-win_amd64.whl (38.1 MB)
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#     --------------------------------------- 0.5/38.1 MB 2.8 MB/s eta 0:00:14
#    - -------------------------------------- 1.0/38.1 MB 2.8 MB/s eta 0:00:14
#    - -------------------------------------- 1.6/38.1 MB 2.8 MB/s eta 0:00:14
#    -- ------------------------------------- 2.1/38.1 MB 2.8 MB/s eta 0:00:13
#    --- ------------------------------------ 2.9/38.1 MB 2.8 MB/s eta 0:00:13
#    --- ------------------------------------ 3.4/38.1 MB 2.8 MB/s eta 0:00:13
#    ---- ----------------------------------- 4.2/38.1 MB 2.8 MB/s eta 0:00:12
#    ---- ----------------------------------- 4.7/38.1 MB 2.9 MB/s eta 0:00:12
#    ----- ----------------------------------
py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.9 MB 5.6 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/9.9 MB 5.6 MB/s eta 0:00:02
#    -------------- ------------------------- 3.7/9.9 MB 5.7 MB/s eta 0:00:02
#    ------------------- -------------------- 4.7/9.9 MB 5.7 MB/s eta 0:00:01
#    ------------------------ --------------- 6.0/9.9 MB 5.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.3/9.9 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.7/9.9 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 5.4 MB/s  0:00:01
# Downloading narwhals-2.16.0-py3-none-any.whl (443 kB)
# Downloading pyyaml-6.0.3-cp312-cp312-win_amd64.whl (154 kB)
# Installing collected packages: typing-extensions, tqdm, threadpoolctl, tabulate, slicer, regex, PyYAML, pyparsing, pillow, patsy, narwhals, MarkupSafe, llvmlite, kiwisolver, joblib, greenlet, graphviz, fonttools, cycler, contourpy, colorlog, cloudpickle, click, attrs, xgboost, sqlalchemy, scikit-learn, plotly, numba, nltk, matplotlib, Mako, lightgbm, jinja2, statsmodels, shap, seaborn, mlxtend, eli5, catboost, alembic, optuna, missingno
#
#     ---------------------------------------  1/43 [tqdm]
#    - --------------------------------------  2/43 [threadpoolctl]
#    ---- -----------------------------------  5/43 [regex]
#    ---- -----------------------------------  5/43 [regex]
#    ---- -----------------------------------  5/43 [regex]
#    ----- ----------------------------------  6/43 [PyYAML]
#    ------ ---------------------------------  7/43 [pyparsing]
#    ------ ---------------------------------  7/43 [pyparsing]
#    ------- --------------------------------  8/43 [pillow]
#    ------- --------------------------------  8/43 [pillow]
#    ------- --------------------------------  8/43 [pillow]
#    ------- --------------------------------  8/43 [pillow]
#    ------- --------------------------------  8/43 [pillow]
#    ------- --------------------------------  8/43 [pillow]
#    ------- --------------------------------  8/43 [pillow]
#    ------- --------------------------------  8/43 [pillow]
#    ------- --------------------------------  8/43 [pillow]
#    -------- -------------------------------  9/43 [patsy]
#    -------- -------------------------------  9/43 [patsy]
#    -------- -------------------------------  9/43 [patsy]
#    --------- ------------------------------ 10/43 [narwhals]
#    --------- ------------------------------ 10/43 [narwhals]
#    --------- ------------------------------ 10/43 [narwhals]
#    --------- ------------------------------ 10/43 [narwhals]
#    --------- ------------------------------ 10/43 [narwhals]
#    --------- ------------------------------ 10/43 [narwhals]
#    --------- ------------------------------ 10/43 [narwhals]
#    --------- ------------------------------ 10/43 [narwhals]
#    --------- ------------------------------ 10/43 [narwhals]
#    --------- ------------------------------ 10/43 [narwhals]
#    --------- ------------------------------ 10/43 [narwhals]
#    --------- ------------------------------ 10/43 [narwhals]
#    ----------- ---------------------------- 12/43 [llvmlite]
#    ----------- ---------------------------- 12/43 [llvmlite]
#    ----------- ---------------------------- 12/43 [llvmlite]
#    ----------- ---------------------------- 12/43 [llvmlite]
#    ----------- ---------------------------- 12/43 [llvmlite]
#    ----------- ---------------------------- 12/43 [llvmlite]
#    ----------- ---------------------------- 12/43 [llvmlite]
#    ----------- ---------------------------- 12/43 [llvmlite]
#    ----------- ---------------------------- 12/43 [llvmlite]
#    ----------- ---------------------------- 12/43 [llvmlite]
#    ----------- ---------------------------- 12/43 [llvmlite]
#    ------------ --------------------------- 13/43 [kiwisolver]
#    ------------- -------------------------- 14/43 [joblib]
#    ------------- -------------------------- 14/43 [joblib]
#    ------------- -------------------------- 14/43 [joblib]
#    ------------- -------------------------- 14/43 [joblib]
#    ------------- -------------------------- 14/43 [joblib]
#    ------------- -------------------------- 14/43 [joblib]
#    ------------- -------------------------- 15/43 [greenlet]
#    ------------- -------------------------- 15/43 [greenlet]
#    -------------- ------------------------- 16/43 [graphviz]
#    -------------- ------------------------- 16/43 [graphviz]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    --------------- ------------------------ 17/43 [fonttools]
#    ----------------- ---------------------- 19/43 [contourpy]
#    ----------------- ---------------------- 19/43 [contourpy]
#    -------------------- ------------------- 22/43 [click]
#    -------------------- ------------------- 22/43 [click]
#    --------------------- ------------------ 23/43 [attrs]
#    ---------------------- ----------------- 24/43 [xgboost]
#    ---------------------- ----------------- 24/43 [xgboost]
#    ---------------------- ----------------- 24/43 [xgboost]
#    ---------------------- ----------------- 24/43 [xgboost]
#    ---------------------- ----------------- 24/43 [xgboost]
#    ---------------------- ----------------- 24/43 [xgboost]
#    ---------------------- ----------------- 24/43 [xgboost]
#    ---------------------- ----------------- 24/43 [xgboost]
#    ---------------------- ----------------- 24/43 [xgboost]
#    ---------------------- ----------------- 24/43 [xgboost]
#    ---------------------- ----------------- 24/43 [xgboost]
#    ---------------------- ----------------- 24/43 [xgboost]
#    ---------------------- ----------------- 24/43 [xgboost]
#    ---------------------- ----------------- 24/43 [xgboost]
#    ---------------------- ----------------- 24/43 [xgboost]
#    ---------------------- ----------------- 24/43 [xgboost]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ----------------------- ---------------- 25/43 [sqlalchemy]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------ --------------- 26/43 [scikit-learn]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    ------------------------- -------------- 27/43 [plotly]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    -------------------------- ------------- 29/43 [nltk]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    --------------------------- ------------ 30/43 [matplotlib]
#    ---------------------------- ----------- 31/43 [Mako]
#    ---------------------------- ----------- 31/43 [Mako]
#    ----------------------------- ---------- 32/43 [lightgbm]
#    ----------------------------- ---------- 32/43 [lightgbm]
#    ------------------------------ --------- 33/43 [jinja2]
#    ------------------------------ --------- 33/43 [jinja2]
#    ------------------------------ --------- 33/43 [jinja2]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    ------------------------------- -------- 34/43 [statsmodels]
#    -------------------------------- ------- 35/43 [shap]
#    -------------------------------- ------- 35/43 [shap]
#    -------------------------------- ------- 35/43 [shap]
#    -------------------------------- ------- 35/43 [shap]
#    -------------------------------- ------- 35/43 [shap]
#    -------------------------------- ------- 35/43 [shap]
#    -------------------------------- ------- 35/43 [shap]
#    --------------------------------- ------ 36/43 [seaborn]
#    --------------------------------- ------ 36/43 [seaborn]
#    --------------------------------- ------ 36/43 [seaborn]
#    --------------------------------- ------ 36/43 [seaborn]
#    --------------------------------- ------ 36/43 [seaborn]
#    ---------------------------------- ----- 37/43 [mlxtend]
#    ---------------------------------- ----- 37/43 [mlxtend]
#    ---------------------------------- ----- 37/43 [mlxtend]
#    ---------------------------------- ----- 37/43 [mlxtend]
#    ---------------------------------- ----- 37/43 [mlxtend]
#    ---------------------------------- ----- 37/43 [mlxtend]
#    ----------------------------------- ---- 38/43 [eli5]
#    ----------------------------------- ---- 38/43 [eli5]
#    ----------------------------------- ---- 38/43 [eli5]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------ --- 39/43 [catboost]
#    ------------------------------------- -- 40/43 [alembic]
#    ------------------------------------- -- 40/43 [alembic]
#    ------------------------------------- -- 40/43 [alembic]
#    ------------------------------------- -- 40/43 [alembic]
#    ------------------------------------- -- 40/43 [alembic]
#    -------------------------------------- - 41/43 [optuna]
#    -------------------------------------- - 41/43 [optuna]
#    -------------------------------------- - 41/43 [optuna]
#    -------------------------------------- - 41/43 [optuna]
#    -------------------------------------- - 41/43 [optuna]
#    -------------------------------------- - 41/43 [optuna]
#    -------------------------------------- - 41/43 [optuna]
#    -------------------------------------- - 41/43 [optuna]
#    -------------------------------------- - 41/43 [optuna]
#    -------------------------------------- - 41/43 [optuna]
#    -------------------------------------- - 41/43 [optuna]
#    -------------------------------------- - 41/43 [optuna]
#    ---------------------------------------- 43/43 [missingno]
#
# Successfully installed Mako-1.3.10 MarkupSafe-3.0.3 PyYAML-6.0.3 alembic-1.18.4 attrs-25.4.0 catboost-1.2.8 click-8.3.1 cloudpickle-3.1.2 colorlog-6.10.1 contourpy-1.3.3 cycler-0.12.1 eli5-0.16.0 fonttools-4.61.1 graphviz-0.21 greenlet-3.3.1 jinja2-3.1.6 joblib-1.5.3 kiwisolver-1.4.9 lightgbm-4.6.0 llvmlite-0.46.0 matplotlib-3.10.0 missingno-0.5.2 mlxtend-0.23.4 narwhals-2.16.0 nltk-3.9.1 numba-0.64.0 optuna-4.4.0 patsy-1.0.2 pillow-12.1.1 plotly-6.5.2 pyparsing-3.3.2 regex-2026.1.15 scikit-learn-1.6.1 seaborn-0.13.2 shap-0.50.0 slicer-0.0.8 sqlalchemy-2.0.46 statsmodels-0.14.6 tabulate-0.9.0 threadpoolctl-3.6.0 tqdm-4.67.3 typing-extensions-4.15.0 xgboost-3.1.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## **Настройка локальной среды: [venv](https://docs.python.org/3/library/venv.html)**

# %% [markdown]
# **Версия Python: 3.12.x**
#
# На других версиях Python данный способ может не работать.

# %% [markdown]
# Откройте терминал (`cmd` в Windows или `Terminal` в macOS/Linux).

# %%
python --version # узнать, какая версия Python установлена по умолчанию

# %% [markdown]
# Если по умолчанию в системе используется версия Python, отличная от 3.12.x, рекомендуется использовать другие способы настройки (Conda или Google Colab/Kaggle) или [установить pyenv](https://github.com/pyenv/pyenv?tab=readme-ov-file#installation) и использовать его для [установки и использования нужной версии python](github.com/pyenv/pyenv?tab=readme-ov-file#install-additional-python-versions): `pyenv install 3.12.12` (для установки) и `pyenv global 3.12.12` (для использования версии 3.12.12).

# %% [markdown]
# ### **Шаг 1. Создание окружения**

# %% [markdown]
# В папке с файлами для курса (рабочая папка, в рамках которой вы будете использовать окружение):

# %%
python -m venv ml2me # можно использовать другое имя окружения (вместо ml2me)

# %% [markdown]
# ### **Шаг 2. Активация окружения**

# %% [markdown]
# - **Windows (PowerShell/CMD):**

# %%
.\ml2me\Scripts\activate # или другое имя окружения (вместо ml2me)

# %% [markdown]
# - **macOS/Linux:**

# %%
source ./ml2me/bin/activate # или другое имя окружения (вместо ml2me)

# %% [markdown]
# ### **Шаг 3. Установка зависимостей с помощью `requirements.txt`**

# %% [markdown]
# Загрузите файл `requirements.txt` в папку с файлами для курса.

# %%
pip install -r requirements.txt

# %% [markdown]
# ### **Шаг 4. Настройка Jupyter**

# %%
pip install ipykernel
python -m ipykernel install --user --name=ml2me # или другое имя окружения (вместо ml2me)

# %% [markdown]
# После настройки выберите созданное окружение через интерфейс в IDE (например, `Select Kernel` в VSCode, `Kernel` в Jupyter Notebook).

# %% [markdown]
# ## **Настройка локальной среды: [Conda](https://docs.conda.io/projects/conda/en/latest/user-guide/index.html)**

# %% [markdown]
# Установите [Anaconda](https://www.anaconda.com/docs/getting-started/anaconda/install) или [Miniconda](https://www.anaconda.com/docs/getting-started/miniconda/install).

# %% [markdown]
# ### **Шаг 1. Создание окружения**

# %% [markdown]
# Откройте терминал (`cmd` в Windows или `Terminal` в macOS/Linux) и загрузите файл `environment.yml`.

# %%
conda env create -f environment.yml

# %% [markdown]
# ### **Шаг 2. Активация окружения**

# %%
conda activate ml2me

# %% [markdown]
# ### **Шаг 3. Настройка Jupyter**

# %%
python -m ipykernel install --user --name=ml2me # можно использовать другое имя окружения (вместо ml2me)

# %% [markdown]
# После настройки выберите созданное окружение через интерфейс в IDE (например, `Select Kernel` в VSCode, `Kernel` в Jupyter Notebook).
