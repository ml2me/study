# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import numpy as np
# %matplotlib inline

# %%
DATA_PATH = 'https://covid.ourworldindata.org/data/owid-covid-data.csv'

# %%
covid_data = pd.read_csv(DATA_PATH)

# %%
# Let's drop aggregated data like OWID*
OWID_index = covid_data.loc[covid_data['iso_code'].str.contains('OWID')].index

covid_data = covid_data.drop(OWID_index)

# %% [markdown]
# Построение описывающей модели, дамми-переменные для стран и периода после начала вакцинации, нормировка и регуляризация.
#
#
# ex_mort =
# b0 +
# b1 * country_dummy +
# b2 * num_sick +
# b3 * time +
# b4 * dummy_date_vacc +
# (b5 * time*dummy_date_vacc) +
# ...

# %%
covid_data.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
#        'population_density', 'median_age', 'aged_65_older', 'aged_70_older',
#        'gdp_per_capita', 'extreme_poverty', 'cardiovasc_death_rate',
#        'diabetes_prevalence', 'female_smokers', 'male_smokers',
#        'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'population',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality', 'excess_mortality_cumulative_per_million'],
#       dtype='object')

# %%
covid_data['date'] = pd.to_datetime(covid_data['date'])

# %%
covid_data = covid_data.loc[(covid_data['date'] < '2022-11-01')]

# %%
covid_data.plot.scatter(x='date',y='new_deaths_smoothed_per_million')
# Out:
# <AxesSubplot: xlabel='date', ylabel='new_deaths_smoothed_per_million'>

# %%
covid_data['date'].hist()
# Out:
# <AxesSubplot: >

# %%
country_dummies = pd.get_dummies(covid_data['iso_code'])

# %%
country_dummies.head()
# Out:
#      ABW   AFG    AGO    AIA    ALB    AND    ARE    ARG    ARM    ASM  ...  \
# 0  False  True  False  False  False  False  False  False  False  False  ...
# 1  False  True  False  False  False  False  False  False  False  False  ...
# 2  False  True  False  False  False  False  False  False  False  False  ...
# 3  False  True  False  False  False  False  False  False  False  False  ...
# 4  False  True  False  False  False  False  False  False  False  False  ...
#
#      VGB    VIR    VNM    VUT    WLF    WSM    YEM    ZAF    ZMB    ZWE
# 0  False  False  False  False  False  False  False  False  False  False
# 1  False  False  False  False  False  False  False  False  False  False
# 2  False  False  False  False  False  False  False  False  False  False
# 3  False  False  False  False  False  False  False  False  False  False
# 4  False  False  False  False  False  False  False  False  False  False
#
# [5 rows x 237 columns]

# %%
covid_data[country_dummies.columns] = country_dummies
# Out:
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies
# <ipython-input-12-2b96580c1e84>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[country_dummies.columns] = country_dummies

# %%
# Fill NaN forward:

for country in covid_data['iso_code'].unique():

    temp = covid_data.loc[covid_data['iso_code'] == country, 'people_vaccinated_per_hundred'].copy()
    temp.fillna(method = 'ffill', inplace=True)
    covid_data.loc[covid_data['iso_code'] == country, 'people_vaccinated_per_hundred'] = temp

# %%
# Let's see... it works!

country = covid_data.loc[covid_data['iso_code'] == 'AFG']

country.plot(kind='scatter',x='date',y='people_vaccinated_per_hundred', figsize=(15,10))
# Out:
# <AxesSubplot: xlabel='date', ylabel='people_vaccinated_per_hundred'>

# %%
# Here is the correction for NaN, should be zeros:

covid_data['people_vaccinated_per_hundred'].fillna(0, inplace=True)

# %%
# Check it's non-decreasing

for country in covid_data['iso_code'].unique():
    vec_to_check = \
    covid_data.loc[covid_data['iso_code'] == country, 'people_vaccinated_per_hundred'] - \
    covid_data.loc[covid_data['iso_code'] == country, 'people_vaccinated_per_hundred'].shift(1)

    if any(vec_to_check<0):
        print(country)
        print(vec_to_check.loc[vec_to_check < 0])

# %%
covid_data['people_vaccinated_per_hundred'].describe()
# Out:
# count    243350.000000
# mean         23.597520
# std          31.088834
# min           0.000000
# 25%           0.000000
# 50%           1.330000
# 75%          49.400000
# max         128.760000
# Name: people_vaccinated_per_hundred, dtype: float64

# %%
# Период после 1% вакцинированных, можно играться с порогом

covid_data['vax_period'] = (covid_data['people_vaccinated_per_hundred'] > 1).astype(int)
# Out:
# <ipython-input-18-a5d431d1acf7>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data['vax_period'] = (covid_data['people_vaccinated_per_hundred'] > 1).astype(int)

# %%
# Сколько прошло дней в штуках с начала наблюдений для страны

for country in covid_data['iso_code'].unique():
    min_country_date = covid_data.loc[covid_data['iso_code'] == country, 'date'].min()
    covid_data.loc[covid_data['iso_code'] == country, 'day_0_covid_country'] = min_country_date

covid_data['days_covid'] = (covid_data['date'] - covid_data['day_0_covid_country']).dt.days
# Out:
# <ipython-input-19-3bdf4ad91294>:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data.loc[covid_data['iso_code'] == country, 'day_0_covid_country'] = min_country_date
# <ipython-input-19-3bdf4ad91294>:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data['days_covid'] = (covid_data['date'] - covid_data['day_0_covid_country']).dt.days

# %%
# Сколько новых кейсов Ковид (нормировка на 1 млн населения), дамми для периода после вакцинации

covid_data['v_new_cases_per_million'] = covid_data['new_cases_per_million'] * covid_data['vax_period']
# Out:
# <ipython-input-20-4f6e9184f58e>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data['v_new_cases_per_million'] = covid_data['new_cases_per_million'] * covid_data['vax_period']

# %%
# Дни после начала на дамми для периода после вакцинации

# covid_data['v_days_covid'] = covid_data['days_covid'] * covid_data['vax_period']

# %%
# Дамми для года

covid_data['year'] = covid_data['date'].dt.year

year = pd.get_dummies(covid_data['year'])
# Out:
# <ipython-input-22-25d105e3604d>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data['year'] = covid_data['date'].dt.year

# %%
year
# Out:
#          2020   2021   2022
# 0        True  False  False
# 1        True  False  False
# 2        True  False  False
# 3        True  False  False
# 4        True  False  False
# ...       ...    ...    ...
# 348212  False  False   True
# 348213  False  False   True
# 348214  False  False   True
# 348215  False  False   True
# 348216  False  False   True
#
# [243350 rows x 3 columns]

# %%
covid_data[['2020','2021','2022']] = year[[2020,2021,2022]]
# Out:
# <ipython-input-24-1088d2a239fa>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[['2020','2021','2022']] = year[[2020,2021,2022]]
# <ipython-input-24-1088d2a239fa>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[['2020','2021','2022']] = year[[2020,2021,2022]]
# <ipython-input-24-1088d2a239fa>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data[['2020','2021','2022']] = year[[2020,2021,2022]]

# %%
# Immunity for the share of people 30 days after vaccination

from datetime import timedelta

covid_data['vac_30'] = 0

for i, country in enumerate(covid_data['iso_code'].unique()):
    
#     if i == 1:
#         break
    
    country_data = covid_data.loc[covid_data['iso_code'] == country, \
                                  ['date','people_vaccinated_per_hundred']].copy()
      
    country_data['date2'] = country_data['date'] + timedelta(days=30) 
    

    temp = country_data.set_index('date').join(\
        country_data.set_index('date2'), rsuffix='r')
    
    temp = temp['people_vaccinated_per_hundredr'].values #.fillna(0).values
    
    covid_data.loc[covid_data['iso_code'] == country, \
                                'vac_30'] = \
                                temp
# Out:
# <ipython-input-25-7ec33d6f4489>:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data['vac_30'] = 0

# %%
# stringency_index for the share of people 14 days after it is calculated

from datetime import timedelta

covid_data['si_14'] = 0

for i, country in enumerate(covid_data['iso_code'].unique()):
    
#     if i == 1:
#         break
    
    country_data = covid_data.loc[covid_data['iso_code'] == country, \
                                  ['date','stringency_index']].copy()
      
    country_data['date2'] = country_data['date'] + timedelta(days=14) 
    

    temp = country_data.set_index('date').join(\
        country_data.set_index('date2'), rsuffix='r')
    
    temp = temp['stringency_indexr'].values #.fillna(0).values
    
    covid_data.loc[covid_data['iso_code'] == country, \
                                'si_14'] = \
                                temp
# Out:
# <ipython-input-26-19a78f82ab92>:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   covid_data['si_14'] = 0

# %%
for i, country in enumerate([['RUS']]):#pd.DataFrame(covid_data['iso_code'].unique()).sample(10).values):
    print(i, country[0])
    covid_data.loc[covid_data['iso_code'] == country[0], 'vac_30'].plot(figsize=(15,10), c='red')
    covid_data.loc[covid_data['iso_code'] == country[0], 'people_vaccinated_per_hundred'].plot(figsize=(15,10))
# Out:
# 0 RUS

# %%
for i, country in enumerate([['RUS']]):#pd.DataFrame(covid_data['iso_code'].unique()).sample(10).values):
    print(i, country[0])
    covid_data.loc[covid_data['iso_code'] == country[0], 'si_14'].plot(figsize=(15,10), c='red')
    covid_data.loc[covid_data['iso_code'] == country[0], 'stringency_index'].plot(figsize=(15,10))
# Out:
# 0 RUS

# %%
# Choose only countries with deaths in 2020 > 1000

temp = covid_data.groupby(['iso_code', '2020'])['new_deaths'].sum().reset_index()

temp = temp.loc[(temp['2020'] == 1) & (temp['new_deaths'] > 1000), 'iso_code']

country_1K = list(temp.values)

covid_data_1K = covid_data.loc[covid_data['iso_code'].isin(country_1K)].copy()

# %%
data = covid_data_1K[
        country_1K +
        ['2020', '2021', '2022'] +
        [
        'vax_period',
        'days_covid',
#        'v_days_covid',
#        'stringency_index',
        'si_14',
#        'v_stringency',
        'new_cases_per_million',
#        'v_new_cases_per_million',
#        'people_vaccinated_per_hundred',
        'vac_30',
        'aged_65_older',
        'new_deaths',
#    'excess_mortality'
]]

# %%
data = data.dropna()

X = data.iloc[:,:-1] # Take y out

y = data['new_deaths']

# %%
# Лестница в небеса

sorted_death = pd.DataFrame(sorted(y))
sorted_death['x'] = sorted_death.index
sorted_death['y'] = np.log10(sorted_death[0]); del sorted_death[0]

sorted_death.plot.scatter(figsize=(15,10), x='x', y='y')
# Out:
# C:\Users\komarov\AppData\Roaming\Python\Python38\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <AxesSubplot: xlabel='x', ylabel='y'>

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=0)

# %%
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_val_scaled = scaler.transform(X_val)

# %%
X.shape, X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((80228, 92), (60171, 92), (20057, 92), (60171,), (20057,))

# %%
# Train, normalized above

reg_train = linear_model.Ridge(alpha=1, random_state=1)

reg_train.fit(X_train_scaled, y_train.values)
# Out:
# Ridge(alpha=1, random_state=1)

# %%
from eli5 import show_weights

show_weights(reg_train, feature_names=X_train.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +106.649
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         USA
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.21%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +76.068
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.20%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +69.384
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         BRA
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.33%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +49.376
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         IND
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.79%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +46.669
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         new_cases_per_million
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.95%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +34.372
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         RUS
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.80%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +29.825
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         MEX
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.03%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +28.640
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         days_covid
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.64%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +25.564
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         si_14
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.40%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +21.889
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vax_period
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.30%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +17.743
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         PER
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.81%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +15.539
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         GBR
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.14%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +10.159
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ITA
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.17%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +10.055
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         IDN
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 96.17%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 13 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 96.17%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 58 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 96.17%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -10.074
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         DZA
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 96.12%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -10.244
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         LBY
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 96.10%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -10.336
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         KEN
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 96.08%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -10.395
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         SVN
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 95.94%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -10.913
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         GEO
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 86.03%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -63.884
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vac_30
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>

# %%
import eli5
from eli5.sklearn import PermutationImportance

perm = PermutationImportance(reg_train, random_state=1).fit(X_val_scaled, y_val.values)
eli5.show_weights(perm, feature_names = X_val.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3269
#
#                     &plusmn; 0.0115
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 USA
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.09%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1199
#
#                     &plusmn; 0.0033
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BRA
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0980
#
#                     &plusmn; 0.0027
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 vac_30
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.46%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0662
#
#                     &plusmn; 0.0013
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 IND
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.78%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0480
#
#                     &plusmn; 0.0019
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 new_cases_per_million
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.52%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0268
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 RUS
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.96%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0222
#
#                     &plusmn; 0.0014
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MEX
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.41%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0176
#
#                     &plusmn; 0.0008
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 days_covid
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.44%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0173
#
#                     &plusmn; 0.0013
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 si_14
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.11%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0113
#
#                     &plusmn; 0.0014
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 vax_period
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.67%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0068
#
#                     &plusmn; 0.0008
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 GBR
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.81%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0058
#
#                     &plusmn; 0.0008
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PER
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.24%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0031
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ITA
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.29%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0028
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 KEN
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.30%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0027
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LBY
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.34%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0025
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 GEO
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.35%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0024
#
#                     &plusmn; 0.0009
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DZA
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.38%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0023
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-ali

# %%
print(list(X.columns).index('USA'))
idx = X_val.iloc[:,80] == 1
# Out:
# 80

# %%
y_pred = reg_train.predict(X_val_scaled[idx,:])
y_pred[y_pred<0] = 0

# %%
usa = pd.DataFrame(X_val.loc[idx, 'days_covid'])
usa['true'] = y_val.values[idx]
usa['pred'] = y_pred

# %%
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(15, 10))

plt.scatter(x=usa['days_covid'], y=usa['true'], alpha=0.5, c='red')
plt.scatter(x=usa['days_covid'], y=usa['pred'], alpha=0.5, c='blue')

plt.show()

# %%
# y_pred_all = reg_train.predict(X_val_scaled)
# y_pred_all[y_pred_all<0] = 0

# all = pd.DataFrame(X_val['days_covid'])
# all['true'] = y_val.values
# all['pred'] = y_pred_all

# figure(figsize=(15, 10))
# plt.scatter(x=all['days_covid'], y=all['true'], alpha=0.5, c='red')
# plt.scatter(x=all['days_covid'], y=all['pred'], alpha=0.5, c='blue')
# plt.show()

# %%
# MAE on USA

from sklearn.metrics import median_absolute_error

mae = median_absolute_error(usa['true'], usa['pred'])
string_score = f"MAE on dataset: {mae:.2f}"
print (string_score)
# Out:
# MAE on dataset: 570.52

# %%
fig, ax = plt.subplots(figsize=(15, 15))
plt.scatter(usa["true"], usa["pred"])
ax.plot([0, 2000], [0, 2000], transform=ax.transAxes, ls="--", c="red")
plt.text(50, 150, string_score)
plt.title("Ridge model, USA, reg = 1")
plt.ylabel("Model predictions")
plt.xlabel("Truths")
plt.xlim([0, 1300])
_ = plt.ylim([0, 1300])

# %%
# MAE on all

y_pred = reg_train.predict(X_val)
y_pred[y_pred<0] = 0
mae = median_absolute_error(y_val, y_pred)
string_score = f"MAE on dataset: {mae:.2f}"
print (string_score)
# Out:
# MAE on dataset: 19390.86
# C:\Users\komarov\AppData\Roaming\Python\Python38\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but Ridge was fitted without feature names
#   warnings.warn(

# %%
from sklearn.ensemble import RandomForestRegressor
rfm = RandomForestRegressor(n_estimators=100,
                                  random_state=0).fit(X_train, y_train)

# %%
from sklearn.inspection import PartialDependenceDisplay
PartialDependenceDisplay.from_estimator(rfm, X_val, ['vac_30'], centered=False)

# %%
perm = PermutationImportance(rfm, random_state=1).fit(X_val, y_val)
eli5.show_weights(perm, feature_names = X_val.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.8608
#
#                     &plusmn; 0.0856
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 new_cases_per_million
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.35%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4475
#
#                     &plusmn; 0.0156
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 USA
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2750
#
#                     &plusmn; 0.0228
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 IND
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.76%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2424
#
#                     &plusmn; 0.0292
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 si_14
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.77%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2012
#
#                     &plusmn; 0.0264
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FRA
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.78%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2006
#
#                     &plusmn; 0.0263
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BRA
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.71%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1288
#
#                     &plusmn; 0.0214
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 days_covid
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.53%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1013
#
#                     &plusmn; 0.0284
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DEU
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.61%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0682
#
#                     &plusmn; 0.0060
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 2021
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.88%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0606
#
#                     &plusmn; 0.0065
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 UKR
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.17%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0526
#
#                     &plusmn; 0.0047
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MEX
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.22%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0512
#
#                     &plusmn; 0.0023
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 RUS
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.27%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0502
#
#                     &plusmn; 0.0098
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 vac_30
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.34%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0483
#
#                     &plusmn; 0.0080
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ESP
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.06%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0306
#
#                     &plusmn; 0.0023
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 IDN
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.46%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0221
#
#                     &plusmn; 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 GBR
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.56%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0201
#
#                     &plusmn; 0.0016
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 aged_65_older
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.82%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0151
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text

# %%
# MAE on all, Random Forest

y_pred = rfm.predict(X_val)
y_pred[y_pred<0] = 0
mae = median_absolute_error(y_val, y_pred)
string_score = f"MAE on dataset: {mae:.2f}"
print (string_score)
# Out:
# MAE on dataset: 1.88

# %%
y_pred = rfm.predict(X_val.loc[idx,:])
y_pred[y_pred<0] = 0
mae = median_absolute_error(y_val.loc[idx], y_pred)
string_score = f"MAE on USA: {mae:.2f}"
print (string_score)
# Out:
# MAE on USA: 130.00

# %%
print(rfm.score(X_val, y_val), '\n')

# from sklearn.inspection import permutation_importance
# r = permutation_importance(rfm, X_val, y_val,\
#                             n_repeats=30, \
#                             random_state=0)

# for j,i in enumerate(r.importances_mean.argsort()[::-1]):
#     if j == 10:
#         break
#     if r.importances_mean[i] - 2 * r.importances_std[i] > 0:
#         print(f"{X_val.columns.to_list()[i]:<8}" \
#                 f"{r.importances_mean[i]:.3f}" \
#                 f" +/- {r.importances_std[i]:.3f}")
# Out:
# 0.9161555143677489

# %%
# # RandomForest

# from sklearn.inspection import PartialDependenceDisplay
# from time import time

# print("Computing partial dependence plots...")
# tic = time()

# fig, ax = plt.subplots(figsize=(20,20))

# ax.set_title(
#     "Partial dependence of deaths on features\n"
#     "for OWID dataset, with RF")


# display = PartialDependenceDisplay.from_estimator(
#     rfm,
#     X_val,
#     features=['vac_30'],
#     ax=ax, line_kw={"color": "blue"},
#     ice_lines_kw={"color": "orange"},
#     kind='average',
# #    subsample=50,
#     random_state=10,
# )
# print(f"done in {time() - tic:.3f}s")

# %%
usa = pd.DataFrame(X_val.loc[idx, 'days_covid'])
usa['true'] = y_val.values[idx]
usa['pred'] = y_pred

# %%
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(15, 10))

plt.scatter(x=usa['days_covid'], y=usa['true'], alpha=0.5, c='red')
plt.scatter(x=usa['days_covid'], y=usa['pred'], alpha=0.5, c='blue')

plt.show()

# %%
# 100 obs for the USA (random since train_test_split shuffles randomly)

data_for_prediction = X_val[idx].iloc[100:200]

# data_for_prediction.columns

# %%
data_for_prediction[['2020', '2021', '2022', 'vax_period', 'days_covid',
       'new_cases_per_million', 'vac_30', 'si_14']].describe()
# Out:
#        vax_period   days_covid  new_cases_per_million     vac_30       si_14
# count      100.00   100.000000             100.000000  100.00000  100.000000
# mean         0.55   471.920000             245.873190   31.19190   52.607000
# std          0.50   302.668124             319.869907   34.56862   20.671085
# min          0.00    30.000000               0.000000    0.00000    0.000000
# 25%          0.00   206.250000              84.125750    0.00000   38.310000
# 50%          1.00   413.500000             164.026500    6.17500   58.800000
# 75%          1.00   754.000000             310.315750   73.13000   68.980000
# max          1.00  1025.000000            2862.826000   79.54000   75.460000

# %%
import shap  # package used to calculate Shap values

# %%
shap.__version__
# Out:
# '0.43.0'

# %%
# X100 = shap.utils.sample(data_for_prediction, 100)
# X100

# %%
# Create object that can calculate shap values
explainer = shap.TreeExplainer(rfm)

# %%
shap_values = explainer(data_for_prediction)

# %%
# shap_values = explainer.shap_values(data_for_prediction, check_additivity=False)

# %%
shap.initjs()

# Make plot. 
shap.summary_plot(shap_values, data_for_prediction)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %%
shap.dependence_plot(
    "vac_30", shap_values.values, data_for_prediction, interaction_index="si_14"
)

# %%
shap.dependence_plot(
    "vac_30", shap_values.values, data_for_prediction)

# %%
X
# Out:
#           AFG    ALB    ARG    ARM    AUT    AZE    BEL    BGD    BGR    BIH  \
# 30       True  False  False  False  False  False  False  False  False  False
# 31       True  False  False  False  False  False  False  False  False  False
# 32       True  False  False  False  False  False  False  False  False  False
# 33       True  False  False  False  False  False  False  False  False  False
# 34       True  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 338735  False  False  False  False  False  False  False  False  False  False
# 338736  False  False  False  False  False  False  False  False  False  False
# 338737  False  False  False  False  False  False  False  False  False  False
# 338738  False  False  False  False  False  False  False  False  False  False
# 338739  False  False  False  False  False  False  False  False  False  False
#
#         ...    ZAF   2020   2021   2022  vax_period  days_covid  si_14  \
# 30      ...  False   True  False  False           0          30   0.00
# 31      ...  False   True  False  False           0          31   0.00
# 32      ...  False   True  False  False           0          32   0.00
# 33      ...  False   True  False  False           0          33   0.00
# 34      ...  False   True  False  False           0          34   0.00
# ...     ...    ...    ...    ...    ...         ...         ...    ...
# 338735  ...  False  False  False   True           1        1028  13.89
# 338736  ...  False  False  False   True           1        1029  13.89
# 338737  ...  False  False  False   True           1        1030  13.89
# 338738  ...  False  False  False   True           1        1031  13.89
# 338739  ...  False  False  False   True           1        1032  13.89
#
#         new_cases_per_million  vac_30  aged_65_older
# 30                      0.000    0.00          2.581
# 31                      0.000    0.00          2.581
# 32                      0.000    0.00          2.581
# 33                      0.000    0.00          2.581
# 34                      0.000    0.00          2.581
# ...                       ...     ...            ...
# 338735                  1.731   78.29          6.614
# 338736                  1.873   78.29          6.614
# 338737                  2.085   78.29          6.614
# 338738                  0.919   78.29          6.614
# 338739                  0.000   78.29          6.614
#
# [80228 rows x 92 columns]

# %%
with pd.option_context('display.max_rows', 500):
    display(data_for_prediction.iloc[20].loc[data_for_prediction.iloc[20] > 0])
# Out:
# USA                         True
# 2021                        True
# vax_period                     1
# days_covid                   403
# si_14                      71.76
# new_cases_per_million    274.708
# vac_30                      3.17
# aged_65_older             15.413
# Name: 328451, dtype: object

# %%
sample_ind = 20

# %%
shap_values[20].shape
# Out:
# (92,)

# %%
_predicts = rfm.predict(X_train)

# %%
_predicts
# Out:
# array([ 0.  , 24.18,  2.77, ...,  0.  , 18.88,  0.  ])

# %%
_predicts.mean()
# Out:
# 76.10250386398764

# %%
explainer.expected_value
# Out:
# array([76.0571571])

# %%
rfm.predict(data_for_prediction.iloc[20].values.reshape(1,-1))
# Out:
# array([3024.36])

# %%
shap_values
# Out:
# .values =
# array([[-1.10137953e-02,  3.35248416e-03, -1.69445629e+00, ...,
#         -5.33457202e+01,  4.93861579e+00, -3.20358247e+00],
#        [-5.86793167e-02,  7.28664530e-03, -3.08178088e-01, ...,
#         -2.48767335e+02,  3.99702705e+01, -2.93530539e-01],
#        [-1.03402864e-02,  8.47466595e-03, -5.25075513e-01, ...,
#          5.43046321e+01,  2.45154956e+01, -1.38277297e+00],
#        ...,
#        [-1.08602478e-02,  3.11438450e-03, -1.71448441e+00, ...,
#         -1.87256331e-01,  1.26149122e+01, -3.01393726e+00],
#        [-1.10391361e-02,  2.93786512e-03, -1.67363145e+00, ...,
#         -5.48967922e+00,  8.53477101e+00, -3.24067375e+00],
#        [-1.06145759e-02,  5.86685750e-03, -3.80796669e-01, ...,
#         -9.11705974e+01, -2.69360389e+01, -1.00236698e+00]])
#
# .base_values =
# array([76.0571571, 76.0571571, 76.0571571, 76.0571571, 76.0571571,
#        76.0571571, 76.0571571, 76.0571571, 76.0571571, 76.0571571,
#        76.0571571, 76.0571571, 76.0571571, 76.0571571, 76.0571571,
#        76.0571571, 76.0571571, 76.0571571, 76.0571571, 76.0571571,
#        76.0571571, 76.0571571, 76.0571571, 76.0571571, 76.0571571,
#        76.0571571, 76.0571571, 76.0571571, 76.0571571, 76.0571571,
#        76.0571571, 76.0571571, 76.0571571, 76.0571571, 76.0571571,
#        76.0571571, 76.0571571, 76.0571571, 76.0571571, 76.0571571,
#        76.0571571, 76.0571571, 76.0571571, 76.0571571, 76.0571571,
#        76.0571571, 76.0571571, 76.0571571, 76.0571571, 76.0571571,
#        76.0571571, 76.0571571, 76.0571571, 76.0571571, 76.0571571,
#        76.0571571, 76.0571571, 76.0571571, 76.0571571, 76.0571571,
#        76.0571571, 76.0571571, 76.0571571, 76.0571571, 76.0571571,
#        76.0571571, 76.0571571, 76.0571571, 76.0571571, 76.0571571,
#        76.0571571, 76.0571571, 76.0571571, 76.0571571, 76.0571571,
#        76.0571571, 76.0571571, 76.0571571, 76.0571571, 76.0571571,
#        76.0571571, 76.0571571, 76.0571571, 76.0571571, 76.0571571,
#        76.0571571, 76.0571571, 76.0571571, 76.0571571, 76.0571571,
#        76.0571571, 76.0571571, 76.0571571, 76.0571571, 76.0571571,
#        76.0571571, 76.0571571, 76.0571571, 76.0571571, 76.0571571])
#
# .data =
# array([[False, False, False, ..., 163.919, 0.0, 15.413],
#        [False, False, False, ..., 71.176, 76.58, 15.413],
#        [False, False, False, ..., 271.04, 78.97, 15.413],
#        ...,
#        [False, False, False, ..., 164.332, 0.0, 15.413],
#        [False, False, False, ..., 170.738, 0.0, 15.413],
#        [False, False, False, ..., 164.134, 77.53, 15.413]], dtype=object)

# %%
shap.force_plot(explainer.expected_value[0], shap_values.values[sample_ind], data_for_prediction.iloc[sample_ind])
# Out:
# <div id='iIFK09Q2OGKHC2DBTX6FX'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 76.05715710225854, "outValue": 3024.3600011393464, "link": "identity", "featureNames": ["AFG", "ALB", "ARG", "ARM", "AUT", "AZE", "BEL", "BGD", "BGR", "BIH", "BLR", "BOL", "BRA", "CAN", "CHE", "CHL", "CHN", "COL", "CRI", "CZE", "DEU", "DNK", "DOM", "DZA", "ECU", "EGY", "ESP", "ETH", "FRA", "GBR", "GEO", "GRC", "GTM", "HND", "HRV", "HUN", "IDN", "IND", "IRL", "IRN", "IRQ", "ISR", "ITA", "JOR", "JPN", "KAZ", "KEN", "LBN", "LBY", "LTU", "MAR", "MDA", "MEX", "MKD", "MMR", "NGA", "NLD", "NPL", "OMN", "PAK", "PAN", "PER", "PHL", "POL", "PRI", "PRT", "PRY", "PSE", "ROU", "RUS", "SAU", "SDN", "SLV", "SRB", "SVK", "SVN", "SWE", "TUN", "TUR", "UKR", "USA", "VEN", "ZAF", "2020", "2021", "2022", "vax_period", "days_covid", "si_14", "new_cases_per_million", "vac_30", "aged_65_older"], "features": {"0": {"effect": -0.010165580693900207, "value": 0.0}, "1": {"effect": 0.01179917673718268, "value": 0.0}, "2": {"effect": -1.8304581638812127, "value": 0.0}, "4": {"effect": -0.054101000280010705, "value": 0.0}, "5": {"effect": -0.007002489074081641, "value": 0.0}, "6": {"effect": -0.07951648912473593, "value": 0.0}, "7": {"effect": -0.06762693449307397, "value": 0.0}, "8": {"effect": -0.10725220597843749, "value": 0.0}, "9": {"effect": -0.0476682034427792, "value": 0.0}, "10": {"effect": -0.002185782129428347, "value": 0.0}, "11": {"effect": -0.06546263859284318, "value": 0.0}, "12": {"effect": -5.441513261090736, "value": 0.0}, "13": {"effect": -0.17705168773189597, "value": 0.0}, "14": {"effect": -0.00781310396229593, "value": 0.0}, "15": {"effect": -0.5602688755995204, "value": 0.0}, "16": {"effect": -0.06040328461732146, "value": 0.0}, "17": {"effect": -2.0292929571342726, "value": 0.0}, "18": {"effect": -0.003857843574704551, "value": 0.0}, "19": {"effect": -0.3526945220089986, "value": 0.0}, "20": {"effect": -1.42369271414209, "value": 0.0}, "21": {"effect": 0.02961313175410328, "value": 0.0}, "22": {"effect": 0.0028671973479698094, "value": 0.0}, "23": {"effect": -0.009954446369229002, "value": 0.0}, "24": {"effect": -0.10782078063264759, "value": 0.0}, "25": {"effect": -0.03456115025022425, "value": 0.0}, "26": {"effect": -1.947883576810855, "value": 0.0}, "27": {"effect": -0.0032619782389084685, "value": 0.0}, "28": {"effect": -2.044185609077223, "value": 0.0}, "29": {"effect": -2.4243613256147722, "value": 0.0}, "30": {"effect": 0.011072605889070134, "value": 0.0}, "31": {"effect": -0.0026961015100421103, "value": 0.0}, "32": {"effect": -0.015555678238619098, "value": 0.0}, "33": {"effect": -0.011121217949651466, "value": 0.0}, "34": {"effect": -0.007920775644709912, "value": 0.0}, "35": {"effect": -0.2962841651545992, "value": 0.0}, "36": {"effect": -1.237060318268227, "value": 0.0}, "37": {"effect": -6.0561487750575145, "value": 0.0}, "38": {"effect": 0.012645919064322404, "value": 0.0}, "39": {"effect": -1.519429873758327, "value": 0.0}, "40": {"effect": -0.05986152092750545, "value": 0.0}, "41": {"effect": 0.00022646522829724333, "value": 0.0}, "42": {"effect": -0.18236711225494134, "value": 0.0}, "43": {"effect": -0.04165175081893657, "value": 0.0}, "44": {"effect": -0.008969343916637142, "value": 0.0}, "45": {"effect": -0.0688550671894898, "value": 0.0}, "46": {"effect": -0.00026218326576761986, "value": 0.0}, "47": {"effect": 0.0027025957687089185, "value": 0.0}, "48": {"effect": 0.023772133264742052, "value": 0.0}, "49": {"effect": 0.12384594057284204, "value": 0.0}, "50": {"effect": -0.04444657800870374, "value": 0.0}, "51": {"effect": -0.04209980126170065, "value": 0.0}, "52": {"effect": -2.7988355549199198, "value": 0.0}, "54": {"effect": -0.07466158752984992, "value": 0.0}, "55": {"effect": -0.0019349326035387336, "value": 0.0}, "56": {"effect": -0.1390716799556577, "value": 0.0}, "57": {"effect": -0.08655403143796069, "value": 0.0}, "58": {"effect": 0.0008706324331522973, "value": 0.0}, "59": {"effect": -0.06263518973026597, "val ...
#     document.getElementById('iIFK09Q2OGKHC2DBTX6FX')
#   );
# </script>

# %%
shap.force_plot(explainer.expected_value[0], shap_values.values[99], data_for_prediction.iloc[99])
# Out:
# <div id='i41OYX3FYQHBKWB343TGY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 76.05715710225854, "outValue": 131.03999996879458, "link": "identity", "featureNames": ["AFG", "ALB", "ARG", "ARM", "AUT", "AZE", "BEL", "BGD", "BGR", "BIH", "BLR", "BOL", "BRA", "CAN", "CHE", "CHL", "CHN", "COL", "CRI", "CZE", "DEU", "DNK", "DOM", "DZA", "ECU", "EGY", "ESP", "ETH", "FRA", "GBR", "GEO", "GRC", "GTM", "HND", "HRV", "HUN", "IDN", "IND", "IRL", "IRN", "IRQ", "ISR", "ITA", "JOR", "JPN", "KAZ", "KEN", "LBN", "LBY", "LTU", "MAR", "MDA", "MEX", "MKD", "MMR", "NGA", "NLD", "NPL", "OMN", "PAK", "PAN", "PER", "PHL", "POL", "PRI", "PRT", "PRY", "PSE", "ROU", "RUS", "SAU", "SDN", "SLV", "SRB", "SVK", "SVN", "SWE", "TUN", "TUR", "UKR", "USA", "VEN", "ZAF", "2020", "2021", "2022", "vax_period", "days_covid", "si_14", "new_cases_per_million", "vac_30", "aged_65_older"], "features": {"0": {"effect": -0.01061457593592357, "value": 0.0}, "1": {"effect": 0.005866857502741438, "value": 0.0}, "2": {"effect": -0.38079666907869725, "value": 0.0}, "4": {"effect": -0.010340447902268205, "value": 0.0}, "5": {"effect": 0.005378456425540067, "value": 0.0}, "6": {"effect": -0.07737372405341925, "value": 0.0}, "7": {"effect": -0.049289604645404286, "value": 0.0}, "8": {"effect": -0.11965769389852719, "value": 0.0}, "9": {"effect": -0.042250729229211026, "value": 0.0}, "10": {"effect": -0.01103580414468646, "value": 0.0}, "11": {"effect": -0.05061144715531966, "value": 0.0}, "12": {"effect": -2.9339430007144127, "value": 0.0}, "13": {"effect": -0.10443110075076385, "value": 0.0}, "14": {"effect": -0.0013491519454017062, "value": 0.0}, "15": {"effect": -0.15974864125661145, "value": 0.0}, "16": {"effect": -0.07334873547461308, "value": 0.0}, "17": {"effect": -0.8349201924836519, "value": 0.0}, "18": {"effect": -0.005409775160436888, "value": 0.0}, "19": {"effect": -0.07120112192956547, "value": 0.0}, "20": {"effect": -0.8547246753267059, "value": 0.0}, "21": {"effect": 0.034673437216458186, "value": 0.0}, "22": {"effect": 0.003515011695507948, "value": 0.0}, "23": {"effect": -0.00926252655277381, "value": 0.0}, "24": {"effect": -0.09398832351991654, "value": 0.0}, "25": {"effect": -0.040615656224523525, "value": 0.0}, "26": {"effect": -0.7865142147648962, "value": 0.0}, "27": {"effect": -0.0028474829469388088, "value": 0.0}, "28": {"effect": -0.8136310937050398, "value": 0.0}, "29": {"effect": -1.2629486939772148, "value": 0.0}, "30": {"effect": -0.0017108500857698238, "value": 0.0}, "31": {"effect": -0.0013765747453827058, "value": 0.0}, "32": {"effect": -0.042818394352305715, "value": 0.0}, "33": {"effect": -0.004885410680742579, "value": 0.0}, "34": {"effect": -0.008020566330578014, "value": 0.0}, "35": {"effect": -0.19158716750450414, "value": 0.0}, "36": {"effect": -0.7390633268618365, "value": 0.0}, "37": {"effect": -4.3795984150994896, "value": 0.0}, "38": {"effect": -0.0003345224802920589, "value": 0.0}, "39": {"effect": -0.5650372664606026, "value": 0.0}, "40": {"effect": -0.030402466443795663, "value": 0.0}, "41": {"effect": -0.010107721021417349, "value": 0.0}, "42": {"effect": -0.14893527275014745, "value": 0.0}, "43": {"effect": -0.009172542422530426, "value": 0.0}, "44": {"effect": -0.006255488194258539, "value": 0.0}, "45": {"effect": -0.11790135146185096, "value": 0.0}, "46": {"effect": 6.815513969155449e-06, "value": 0.0}, "47": {"effect": -0.001123196520974623, "value": 0.0}, "48": {"effect": 0.005807610174526648, "value": 0.0}, "49": {"effect": 0.022849632614513837, "value": 0.0}, "50": {"effect": -0.02657312606005919, "value": 0.0}, "51": {"effect": -0.01471233121311265, "value": 0.0}, "52": {"effect": -1.246801357991751, "value": 0.0}, "54": {"effect": -0.036837788524192075, "value": 0.0}, "55": {"effect": -0.0012949208496035405, "value": 0.0}, "56": {"effect": -0.07714706780173189, "value": 0.0}, "57": {"effect": -0.017004891081858566, "value": 0.0}, "58": {"effect": 0.0013253700191772997, "value": 0.0}, "59": {"effect": -0.04 ...
#     document.getElementById('i41OYX3FYQHBKWB343TGY')
#   );
# </script>

# %%
shap.force_plot(explainer.expected_value[0], shap_values.values[0], data_for_prediction.iloc[0])
# Out:
# <div id='iOR21Y0Z2LUSFWBQ8MQJ1'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 76.05715710225854, "outValue": 799.000000005267, "link": "identity", "featureNames": ["AFG", "ALB", "ARG", "ARM", "AUT", "AZE", "BEL", "BGD", "BGR", "BIH", "BLR", "BOL", "BRA", "CAN", "CHE", "CHL", "CHN", "COL", "CRI", "CZE", "DEU", "DNK", "DOM", "DZA", "ECU", "EGY", "ESP", "ETH", "FRA", "GBR", "GEO", "GRC", "GTM", "HND", "HRV", "HUN", "IDN", "IND", "IRL", "IRN", "IRQ", "ISR", "ITA", "JOR", "JPN", "KAZ", "KEN", "LBN", "LBY", "LTU", "MAR", "MDA", "MEX", "MKD", "MMR", "NGA", "NLD", "NPL", "OMN", "PAK", "PAN", "PER", "PHL", "POL", "PRI", "PRT", "PRY", "PSE", "ROU", "RUS", "SAU", "SDN", "SLV", "SRB", "SVK", "SVN", "SWE", "TUN", "TUR", "UKR", "USA", "VEN", "ZAF", "2020", "2021", "2022", "vax_period", "days_covid", "si_14", "new_cases_per_million", "vac_30", "aged_65_older"], "features": {"0": {"effect": -0.011013795293176398, "value": 0.0}, "1": {"effect": 0.0033524841553820225, "value": 0.0}, "2": {"effect": -1.6944562926754225, "value": 0.0}, "4": {"effect": -0.0732734316830385, "value": 0.0}, "5": {"effect": -0.004805217911259716, "value": 0.0}, "6": {"effect": -0.18193415559718573, "value": 0.0}, "7": {"effect": -0.06482006055682604, "value": 0.0}, "8": {"effect": -0.10110891237542384, "value": 0.0}, "9": {"effect": -0.03441977922355234, "value": 0.0}, "10": {"effect": -0.004611519187941857, "value": 0.0}, "11": {"effect": -0.08858161187003483, "value": 0.0}, "12": {"effect": -4.071836059115596, "value": 0.0}, "13": {"effect": -0.22457547261175645, "value": 0.0}, "14": {"effect": -0.01322034065508122, "value": 0.0}, "15": {"effect": -0.5435374785515096, "value": 0.0}, "16": {"effect": -0.06175914101697202, "value": 0.0}, "17": {"effect": -1.3596552634294985, "value": 0.0}, "18": {"effect": -0.00836249404616789, "value": 0.0}, "19": {"effect": -0.25868630244251667, "value": 0.0}, "20": {"effect": -1.3784923965644937, "value": 0.0}, "21": {"effect": 0.03665321571256073, "value": 0.0}, "22": {"effect": 0.0020444343424125856, "value": 0.0}, "23": {"effect": -0.014953903591990744, "value": 0.0}, "24": {"effect": -0.11543229907976785, "value": 0.0}, "25": {"effect": -0.0393974481486544, "value": 0.0}, "26": {"effect": -0.8225727240571059, "value": 0.0}, "27": {"effect": -0.0020338048904404243, "value": 0.0}, "28": {"effect": -2.7487768288495533, "value": 0.0}, "29": {"effect": -1.3617692191885866, "value": 0.0}, "30": {"effect": -0.008267275725858773, "value": 0.0}, "31": {"effect": -0.0016887522576046138, "value": 0.0}, "32": {"effect": -0.013765000870601398, "value": 0.0}, "33": {"effect": -0.01333028776058968, "value": 0.0}, "34": {"effect": -0.008375360615542005, "value": 0.0}, "35": {"effect": -0.2689281554648231, "value": 0.0}, "36": {"effect": -1.2698831561782484, "value": 0.0}, "37": {"effect": -3.9024192772739283, "value": 0.0}, "38": {"effect": 0.005471329179808229, "value": 0.0}, "39": {"effect": -2.277316625708311, "value": 0.0}, "40": {"effect": -0.10844777589438745, "value": 0.0}, "41": {"effect": -0.008193914583090177, "value": 0.0}, "42": {"effect": -0.1999961938767845, "value": 0.0}, "43": {"effect": -0.01507268909822539, "value": 0.0}, "44": {"effect": -0.009769153878053358, "value": 0.0}, "45": {"effect": -0.09619180598756827, "value": 0.0}, "46": {"effect": 0.0008918458994401004, "value": 0.0}, "47": {"effect": -0.006367241336008549, "value": 0.0}, "48": {"effect": 0.013726318793560779, "value": 0.0}, "49": {"effect": 0.05165266798505139, "value": 0.0}, "50": {"effect": -0.0513016849652131, "value": 0.0}, "51": {"effect": -0.015653978022504605, "value": 0.0}, "52": {"effect": -2.499324866091589, "value": 0.0}, "54": {"effect": -0.07066981169756488, "value": 0.0}, "55": {"effect": -0.002321739642186708, "value": 0.0}, "56": {"effect": -0.2532225405651039, "value": 0.0}, "57": {"effect": -0.029050499913080813, "value": 0.0}, "58": {"effect": 0.000708113890319471, "value": 0.0}, "59": {"effect": -0.06325727380293503, "value ...
#     document.getElementById('iOR21Y0Z2LUSFWBQ8MQJ1')
#   );
# </script>

# %%
shap.plots.heatmap(shap_values)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,10))

shap.plots.waterfall(shap_values[2])

# from shap.plots import _waterfall
# _waterfall.waterfall_legacy(explainer.expected_value[0], shap_values[sample_ind], data_for_prediction.iloc[sample_ind])

# %%
# Random 100 obs

data_for_prediction = X_val.sample(100, random_state = 1)

data_for_prediction[['2020','2021','2022','vax_period','days_covid',
                     'new_cases_per_million','vac_30','aged_65_older', 'si_14']].describe()
# Out:
#        vax_period  days_covid  new_cases_per_million      vac_30  \
# count  100.000000  100.000000             100.000000  100.000000
# mean     0.580000  511.380000             190.364430   23.243400
# std      0.496045  261.938646             850.839824   28.679536
# min      0.000000   51.000000               0.000000    0.000000
# 25%      0.000000  270.750000               1.519500    0.000000
# 50%      1.000000  510.000000              19.501500    5.100000
# 75%      1.000000  713.000000             114.345250   46.057500
# max      1.000000  997.000000            8249.080000   88.840000
#
#        aged_65_older      si_14
# count     100.000000  100.00000
# mean       11.415900   52.17090
# std         6.816371   22.05544
# min         2.355000    2.78000
# 25%         5.659000   38.80000
# 50%         8.533000   55.10500
# 75%        18.517000   69.44000
# max        27.049000   96.30000

# %%
# Calculate shap_values for all of X_val 
shap_values = explainer(data_for_prediction)

# Make plot. Index of [1] is explained in text below.
shap.summary_plot(shap_values, data_for_prediction)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %%
shap.dependence_plot(
    "vac_30", shap_values.values, data_for_prediction, interaction_index="si_14"
)

# %%
for i, col in enumerate(data_for_prediction.columns):
    if col == 'vac_30':
        print(i)
# Out:
# 90

# %%
(shap_values.values > 50)[:,90]
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True])

# %%
shap_values.values[99,90]
# Out:
# 86.1065822007393

# %%
data_for_prediction.iloc[99]
# Out:
# AFG                        False
# ALB                        False
# ARG                        False
# ARM                        False
# AUT                        False
#                           ...
# days_covid                   486
# si_14                      73.61
# new_cases_per_million    259.776
# vac_30                      4.64
# aged_65_older              5.989
# Name: 139648, Length: 92, dtype: object

# %%
shap.dependence_plot(
    "vac_30", shap_values.values, data_for_prediction
)

# %%
shap.dependence_plot(
    "vac_30", shap_values.values[:99], data_for_prediction.iloc[:99], interaction_index="si_14"
)

# %%
for country in list(country_dummies.columns):
    if country not in data_for_prediction.columns:
        continue
    if data_for_prediction[country].sum() == 0:
        continue
    print(country, data_for_prediction[country].mean())

# %%
print(list(X.columns).index('RUS'))
ISO_CHOSEN = list(X.columns).index('RUS')

# %%
idx = X_val.iloc[:,ISO_CHOSEN] == 1

# %%
data_for_prediction = X_val[idx].iloc[100:200]

data_for_prediction.columns

# %%
data_for_prediction[['2020', '2021', '2022', 'vax_period', 'days_covid',
       'new_cases_per_million', 'vac_30', 'si_14']].describe()

# %%
import shap  # package used to calculate Shap values

shap.initjs()

# Create object that can calculate shap values
explainer = shap.TreeExplainer(rfm)

# calculate shap values. This is what we will plot.
# Calculate shap_values for all of val_X rather than a single row, to have more data for plot.
shap_values = explainer.shap_values(data_for_prediction, check_additivity=False)

# Make plot. Index of [1] is explained in text below.
shap.summary_plot(shap_values, data_for_prediction)

# %%
y_pred = rfm.predict(X_val.loc[idx,:])
y_pred[y_pred<0] = 0

# %%
rus = pd.DataFrame(X_val.loc[idx, 'days_covid'])
rus['true'] = y_val.values[idx]
rus['pred'] = y_pred

# %%
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(15, 10))

plt.scatter(x=rus['days_covid'], y=rus['true'], alpha=0.5, c='red')
plt.scatter(x=rus['days_covid'], y=rus['pred'], alpha=0.5, c='blue')

plt.show()

# %%
mae = median_absolute_error(rus['true'], rus['pred'])
string_score = f"MAE on RUS: {mae:.2f}"
print (string_score)

# %%
from catboost import Pool, CatBoostRegressor

# %%
for i,col in enumerate(X_train.columns):
    print (i, col)

# %%
train_pool = Pool(X_train, 
                  y_train, 
                  cat_features=[one for one in range(87)])
test_pool = Pool(X_val,
                 y_val,
                 cat_features=[one for one in range(87)]) 

# specify the training parameters 
model = CatBoostRegressor(iterations=20000, 
                          depth=2, 
                          learning_rate=.8,
                          random_seed=1,
                          loss_function='RMSE',
                          verbose=200,    
                          eval_metric='MAE',
                          use_best_model=True
                         )
#train the model
model.fit(X_train, y=y_train, cat_features=[one for one in range(87)], eval_set=test_pool)
# make the prediction using the resulting model
# preds = model.predict(test_pool)
# print(preds)

# %%
model.get_feature_importance(prettified=True)[:10]

# %%
test_pool = Pool(X_val, 
                 cat_features=[one for one in range(87)]) 

# y_pred = model.predict(test_pool)

# y_pred[y_pred<0] = 0

# %%
import shap

explainer = shap.TreeExplainer(model)
shap_values=explainer.shap_values(test_pool)

shap.initjs()
shap.summary_plot(shap_values, X_val)

# %%
shap_values = explainer.shap_values(X_val)
shap.dependence_plot('vac_30', shap_values, X_val)

# %%
ISO_CHOSEN = list(X.columns).index('RUS')

idx = X_val.iloc[:,ISO_CHOSEN] == 1

test_pool = Pool(X_val[idx], 
                 cat_features=[one for one in range(87)]) 

y_pred = model.predict(test_pool)

y_pred[y_pred<0] = 0

# %%
mae = median_absolute_error(y_val.loc[idx], y_pred)
string_score = f"MAE on RUS: {mae:.2f}"
print (string_score)

# %%
rus = pd.DataFrame(X_val.loc[idx, 'days_covid'])
rus['true'] = y_val.values[idx]
rus['pred'] = y_pred

# %%
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(15, 10))

plt.scatter(x=rus['days_covid'], y=rus['true'], alpha=0.5, c='red')
plt.scatter(x=rus['days_covid'], y=rus['pred'], alpha=0.5, c='blue')

plt.show()

# %%
import shap

explainer = shap.TreeExplainer(model)
shap_values=explainer.shap_values(test_pool)

shap.initjs()
shap.summary_plot(shap_values, X_val[idx])

# %%
# shap_values = explainer.shap_values(X_val)
shap.dependence_plot('vac_30', shap_values, X_val[idx])

# %%
ISO_CHOSEN = list(X.columns).index('USA')
idx = X_val.iloc[:,ISO_CHOSEN] == 1

# %%
usa = pd.DataFrame(X_val.loc[idx, 'days_covid'])
usa['true'] = y_val.values[idx]
test_pool = Pool(X_val[idx], 
                 cat_features=[one for one in range(87)]) 
y_pred = model.predict(test_pool)
y_pred[y_pred<0] = 0
usa['pred'] = y_pred

# %%
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(15, 10))

plt.scatter(x=usa['days_covid'], y=usa['true'], alpha=0.5, c='red')
plt.scatter(x=usa['days_covid'], y=usa['pred'], alpha=0.5, c='blue')

plt.show()

# %%
mae = median_absolute_error(y_val.loc[idx], y_pred)
string_score = f"MAE on USA: {mae:.2f}"
print (string_score)

# %%
explainer = shap.TreeExplainer(model)
shap_values=explainer.shap_values(test_pool)

shap.initjs()
shap.summary_plot(shap_values, X_val[idx])

# %%
shap.dependence_plot('vac_30', shap_values, X_val[idx])

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.pipeline import make_pipeline
from sklearn import tree

my_tree = tree.DecisionTreeRegressor(random_state=0)
my_tree.fit(X, y)


mlp = make_pipeline(
    StandardScaler(),
    MLPRegressor(hidden_layer_sizes=(100, 100), \
                 tol=1e-2, max_iter=500, random_state=0),
)
mlp.fit(X_train, y_train)

# %%
# MAE for MLP 

y_pred = mlp.predict(X_val)
y_pred[y_pred<0] = 0
mae = median_absolute_error(y_val.values, y_pred)
string_score = f"MAE on dataset: {mae:.2f}"
print (string_score)

# %%
y_pred = mlp.predict(X_val[idx])
y_pred[y_pred<0] = 0

# %%
usa = pd.DataFrame(X_val.loc[idx, 'days_covid'])
usa['true'] = y_val.values[idx]
usa['pred'] = y_pred

# %%
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(15, 10))

plt.scatter(x=usa['days_covid'], y=usa['true'], alpha=0.5, c='red')
plt.scatter(x=usa['days_covid'], y=usa['pred'], alpha=0.5, c='blue')

plt.show()

# %%
perm2 = PermutationImportance(my_tree, random_state=1).fit(X, y)
eli5.show_weights(perm2, feature_names = X.columns.tolist())

# %%
perm3 = PermutationImportance(mlp, random_state=1).fit(X_val, y_val)
eli5.show_weights(perm3, feature_names = X.columns.tolist())

# %%
imp_voc = dict()

for var, imp in zip(X.columns,my_tree.feature_importances_):
    imp_voc[var] = round(imp, 4)

# %%
#Most important

sorted(imp_voc.items(), key=lambda item: item[1], reverse=True)[:20]

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(my_tree, max_depth=4, fontsize=10, feature_names=X.columns) 
plt.show()

# %%
my_tree.get_depth()

# %%
my_tree.get_n_leaves()

# %%
names = ['vax_period', 'days_covid',
       'new_cases_per_million', 
       'vac_30']

# %%
# Perfect Tree

from sklearn.inspection import PartialDependenceDisplay
from time import time

print("Computing partial dependence plots...")
tic = time()

fig, ax = plt.subplots(figsize=(15, 10))

ax.set_title(
    "Partial dependence of deaths on features\n"
    "for OWID dataset, with Tree")


display = PartialDependenceDisplay.from_estimator(
    my_tree,
    X,
    features=names,
    ax=ax, 
    line_kw={"color": "red"},
    random_state=0
)

print(f"done in {time() - tic:.3f}s")

# %%
# MLP

print("Computing partial dependence plots...")
tic = time()

fig, ax = plt.subplots(figsize=(20,20))

ax.set_title(
    "Partial dependence of deaths on features\n"
    "for OWID dataset, with MLP")


display = PartialDependenceDisplay.from_estimator(
    mlp,
    X,
    features=names,
    ax=ax, line_kw={"color": "blue"},
    ice_lines_kw={"color": "orange"},
    kind='average',
#    subsample=50,
    random_state=10,
)
print(f"done in {time() - tic:.3f}s")

# %%
reg = make_pipeline(
    StandardScaler(),
    linear_model.Ridge(alpha=1, random_state=17),
)

reg.fit(X, y)

print("Computing partial dependence plots...")
tic = time()

fig, ax = plt.subplots(figsize=(15, 10))

ax.set_title(
    "Partial dependence of deaths on features\n"
    "for OWID dataset, with Ridge")


display = PartialDependenceDisplay.from_estimator(
    reg,
    X,
    features=names,
    ax=ax, 
    line_kw={"color": "blue"},
    ice_lines_kw={"color": "orange"},
    kind='average',
#    subsample=50,
    random_state=10,
)
print(f"done in {time() - tic:.3f}s")

# %%
# Excess Mortality

# %%
data = covid_data_1K[
        country_1K +
        ['2020', '2021', '2022'] +
        [
        'vax_period',
        'days_covid',
        'v_days_covid',
#        'stringency_index',
#        'v_stringency',
        'new_cases_per_million',
        'v_new_cases_per_million',
#        'people_vaccinated_per_hundred',
        'vac_30',
#    'new_deaths',
    'excess_mortality'
]]
