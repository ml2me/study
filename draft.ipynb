# %%
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# 2026-04-20 17:04:22

# %%
nnn = datetime.now()  #  .strftime("%Y-%m-%d %H:%M:%S")

ddd = datetime(1962, 3, 19)

p = (ddd - nnn) / 365

p
# Out:
# datetime.timedelta(days=-65, seconds=74868, microseconds=838371)

# %%
from datetime import date, timedelta, datetime

birthday = date(1962, 3, 19)
today = date(datetime.now()) #  date(2026, 4, 20)

dlt = today - birthday

print(dlt.days // (365*3/4 + 366*1/4 ))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       1 from datetime import date, timedelta, datetime
#       2
#       3 birthday = date(1962, 3, 19)
# ----> 4 today = date(datetime.now()) #  date(2026, 4, 20)
#       5
#       6 dlt = today - birthday
#       7
#
# TypeError: 'datetime.datetime' object cannot be interpreted as an integer
